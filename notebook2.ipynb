# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)  # For reproducibility
data = {
    'A': np.random.randn(100),
    'B': np.random.rand(100),
    'C': np.random.randint(1, 100, 100)
}
df = pd.DataFrame(data)
df.head()
# Out:
#           A         B   C
# 0  0.496714  0.417411  98
# 1 -0.138264  0.222108  21
# 2  0.647689  0.119865  30
# 3  1.523030  0.337615  97
# 4 -0.234153  0.942910  28

# %%
df.describe()
# Out:
#                 A           B           C
# count  100.000000  100.000000  100.000000
# mean    -0.103847    0.486206   51.590000
# std      0.908168    0.288144   28.275733
# min     -2.619745    0.005062    2.000000
# 25%     -0.600906    0.241280   26.750000
# 50%     -0.126956    0.507386   49.000000
# 75%      0.405952    0.694676   67.500000
# max      1.852278    0.985650   99.000000

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['A'], label='A')
plt.plot(df['B'], label='B')
plt.plot(df['C'], label='C')
plt.legend()
plt.show()

# %%
df.hist(figsize=(12, 8), bins=20)
plt.show()

# %%
df.boxplot(figsize=(12, 8))
plt.show()

# %%
import seaborn as sns

sns.pairplot(df)
plt.show()

# %%
corr = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=5a9dcdb9-e296-4f65-8ac9-55134a82d1f9' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
